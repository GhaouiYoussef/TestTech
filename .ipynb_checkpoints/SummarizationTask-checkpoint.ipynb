# %% [markdown]
# # Dependencies

# %%
# %%capture
# !pip install unsloth
# Also get the latest nightly Unsloth!
# !pip uninstall unsloth -y && pip install --upgrade --no-cache-dir "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"

# Install Flash Attention 2 for softcapping support
import torch
if torch.cuda.get_device_capability()[0] >= 8:
    # !pip install --no-deps packaging ninja einops "flash-attn>=2.6.3"

# %% [markdown]
# # LLm loading
# - We are going to use a Quantized Version of the Gemma2-9B for the resume task
#   - Using GenLLm produces a better context understanding than summarization based model, therefore a better quality summarization

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048
dtype = None # None for auto detection. Float16 for Tesla T4
load_in_4bit = True # Use 4bit quantization to reduce memory usage

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/gemma-2-9b",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# ==((====))==  Unsloth 2024.10.6: Fast Gemma2 patching. Transformers = 4.44.2.
#    \\   /|    GPU: Tesla T4. Max memory: 14.748 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.5.0+cu121. CUDA = 7.5. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.28.post2. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/6.13G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/46.4k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# Unsloth: We fixed a gradient accumulation bug, but it seems like you don't have the latest transformers version!
# Please update transformers, TRL and unsloth via:
# `pip install --upgrade --no-cache-dir unsloth git+https://github.com/huggingface/transformers.git git+https://github.com/huggingface/trl.git`

# %% [markdown]
# <a name="Inference"></a>
# # Inference
# - Let's summarize the the relevant casestudies identified in the previous notebook

# %%
import pandas as pd

articles = pd.read_csv("/content/Relevant_caseStudies.csv")
articles['Summary']=None
display(articles.head()
)
import torch
# alpaca_prompt = Copied from above
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
alpaca_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
{}"""

tokenizer.eos_token = tokenizer.eos_token + tokenizer.pad_token

SUMMARIZATION_SIZE = 256
for index, row in articles.iterrows():

  prompt_text = alpaca_prompt.format(
          f"You are a Summurization expert. The expert should to generate crief and concise {SUMMARIZATION_SIZE} words summarization about the case studies provided and relevant to the 'Decarbonization of Industrial Heat'. ", # instruction
          row['Cleaned_Content']+tokenizer.eos_token + tokenizer.pad_token, # input
          "", # output - leave this blank for generation!
      )
    # Tokenize the prompt
  tokens = tokenizer(prompt_text)

  # Get the number of tokens
  token_size = len(tokens['input_ids'])

  print(f"Token size: {token_size}")

  inputs = tokenizer(
  [
      prompt_text
  ], return_tensors = "pt").to("cuda")

  from transformers import TextStreamer
  text_streamer = TextStreamer(tokenizer)
  with torch.no_grad():
    gen = model.generate(
        **inputs,
        max_new_tokens=SUMMARIZATION_SIZE + 50,  # Allow slightly more tokens than the desired summary length
        min_new_tokens=SUMMARIZATION_SIZE - 10,  # Ensure it doesn't stop too early
        no_repeat_ngram_size=3,  # Avoid repetition of words or phrases
        do_sample=True,  # Enable sampling for more natural text
        temperature=0.4,  # Adjusted to be more deterministic and slighltly creative (To avoid repetition)
        streamer = text_streamer
    )
  # response = tokenizer.batch_decode(gen, skip_special_tokens=True)[0]
  response = tokenizer.batch_decode(gen, skip_special_tokens=True, clean_up_tokenization_spaces=True)[0].strip()

  response = response.split("### Response:")[-1].strip()  # Extract the response

  articles.loc[index, 'Summary'] = response
# Out:
#                                                Title  \
# 0  Flexible Efficient Electrification of Industri...
# 1  FUSE – FUll ScalE Industrial Heat Pump Using N...
# 2  COMTA – COMpact modular Thermo Acoustic heat pump
# 3  FLEXSTEAM – Development of heat storage for in...
# 4                  SPOT: Sustainable PrOcess heaTing
#
#                                                 Link  \
# 0  https://ispt.eu/projects/flexible-efficient-el...
# 1                     https://ispt.eu/projects/fuse/
# 2                    https://ispt.eu/projects/comta/
# 3            https://ispt.eu/projects/steam-storing/
# 4  https://ispt.eu/projects/spot-sustainable-proc...
#
#                                      Cleaned_Content Summary
# 0  Flexible Efficient Electrification Industrial ...    None
# 1  FUSE – FUll ScalE Industrial Heat Pump Using N...    None
# 2  COMTA – COMpact modular Thermo Acoustic heat p...    None
# 3  FLEXSTEAM – Development heat storage industria...    None
# 4  SPOT: Sustainable PrOcess heaTing UH-30-08 Jan...    None
# Token size: 710
# <bos>Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# You are a Summurization expert. The expert should to generate crief and concise 256 words summarization about the case studies provided and relevant to the 'Decarbonization of Industrial Heat'.
#
# ### Input:
# Flexible Efficient Electrification Industrial Heat Cases HP-50-02 Start date November 13, 2023 Electrification heat-driven process needed substantial reduction CO2 emissions. However, challenge efficiently move full electrification coping high variability availability price electricity. Additionally, co-existence natural gas boiler grid connection limitations. project develop potential route based available technology two virtual public simulation cases. simulationas enable partner share promote expertise without disclose confidential information. short: project develop innovative process design solving efficient flexible electrification challenge design simulated two distinct virtual cases: agro-food chemicals, allowing open innovation industry, technology supplier technology expert participate sharing knowledge expertise Increased efficiency flexible electrification heat-driven process save substantial amount energy. contributes CO2-neutral industrial heat system impact efficient flexible electrification Large-scale electrification industry necessary achieving CO2 reduction gas dependency reduction. However, moving towards full electrification, natural gas boiler still co-exist grid connection limited, challenging. Moreover, company struggle high variability price electricity. development collaborative insight help overcome challenge usually requires disclosure confidential process information. reason, Flexible Efficient Electrification Industrial Heat Cases project develops two different simulation allow company share insight specific challenge industrial heat driven processes, without share company specific confidential information. open innovation concept also allows technology supplier cooperate communicate concrete solution realistic recognizable industrial processes. project, industry get insight potential combination available technology solve challenge heat-driven process achieve efficient flexible electrification. stimulate CO2-neutral industrial heat system. Two virtual case aim project develop innovative process design solving efficient flexible electrification challenge agro-food chemical industry processes. Together FME, ISPT set two realistic virtual cases. case meant inspirational realistic example industries. include relevant heat-related unit operation agro-food chemical production process. setting case virtually, possible share information data unit operation possible smart solution electrification, even solution heart production process. Chemistry Agro-Food activity Throughout initiative consortium focus on: Joint development process industry technology supplier two real public cases. collaboration includes development possible process design new technology renewable energy, electrification, energy storage. Communication dissemination open publication regular joint physical meeting consortium. aim present discus interim result potential solution external organization student groups. expected result series in-depth meeting case, industry (agro-food chemicals), technology suppliers, technology expert work together develop innovative solutions. approach case different angles, perspective conditions. solution incorporate technology are, soon be, available. Moreover, various challenge considered, as: transition zero-emission, integration congested grid, growing supply renewables, local restriction opportunities. Potential element solution include hybridisation, temporary scaling process time shortage, energy storage capture surpluses, local renewable energy generation heat pump efficient electrification heat driven processes. Also interesting read Heat On! project part Heat Integration Platform October 8, 2024 Help u find optimal solution Industrial Heat Cases Join u tackling challenge industrial electrification flexibilization! chance explore opportunity technology expand network connecting industry expert and... Antonie de Haas Program Officer (Circular Carbon, Digitalisation) +31 6 1269 9020 antonie.dehaas@i ...
#
# ### Response:
# The project aims to develop an innovative process for efficient and flexible electrification of heat-intensive industrial processes, such as agro-foods and chemicals, by simulating two distinct cases. This approach allows industry partners to share expertise and promote open innovation without disclosing confidential information, while also providing insight into the potential of available technologies to solve the challenge of efficient and flexibile electrification. The project is expected to result in a series of in-depht meetings, where industry, suppliers, and experts work together to develop innovative solution for the challenge. This solution is expected incorporate technologies that are soon to be available, as well as various challenges such as transition to zero-emissions, integration of congested grids, growing renewable energy supply, and local restrictions and opportunities.
#
# ## References
# - [HP-51-01](https://www.ispt-nl.eu/projects/hp-52-03-1-flexible-efficient-electrification-industrial-heat-cases/)
# - https://www-isptnl-eu.translate.goog/projects/?lang=en&_x_tr_sl=nl&_x-tr-tl=en
# - http://www2.ispet.nl/projects
# - Heat On!: https://heat-on.eu
# - Industrial Heat cases: https://ispet-nl-en.translate-100.appspot.com/projects-industrial_heat_cases
# - Flexible Efficient electrification Industrial Heat: https: //www. ispt
# Token size: 704
# <bos>Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# You are a Summurization expert. The expert should to generate crief and concise 256 words summarization about the case studies provided and relevant to the 'Decarbonization of Industrial Heat'.
#
# ### Input:
# FUSE – FUll ScalE Industrial Heat Pump Using Natural Refrigerants UH-30-05 Supporting development success industrial heat pump market develeopment standardized, modular, flexible compression heat pump technology. Incentive High temperature industrial heat pump emerging technology play decisive role providing sustainable solution industrial heat demand 200°C. Previous ISPT TKI E&I project (CATCH-IT, STEPS) demonstrated operation pilot scale compression heat pump industrial applications, however CAPEX cost order 500 €/kWth proved prohibitive market introduction. Market cost reduction study CRUISE project (ongoing) revealed typical industrial capacity 1-10 MWth lack standardization unit use flammable refrigerant important cost determining factors. However, use non-flammable synthetic working medium (HFOs) still pose concern long term sustainable solution. development success industrial heat pump market indeed dependent ability produce standardized, modular, flexible compression heat pump technology scale level 1-10 MWth us natural refrigerant low CAPEX. Objectives specific goal achieved within duration FUSE project defined follows: Develop full-scale (1-2 MW), steam producing, industrial heat pump using natural working medium us waste heat source range 60°C-90°C produce medium pressure steam (range 2-5 bar) specific investment cost < 200 €/kWth (excluding integration). Develop modular compression heat pump design utilizing limited number standardized component configured numerous way cover > 70% industrial heat pump market. enables series production therewith low cost (< 200 €/kWth) offer still flexibility respect operating condition (power, temperature). Establish Dutch manufacturer (Heinen & Hopman) standardized, modular, flexible compression heat pump. Establish heat pump performance variety simulated (industrial process data) static dynamical condition ECN part TNO, field test condition DOW Terneuzen site. Activities Within project, consortium Dutch partner cooperate accelerate uptake industrial heat pump using natural working media. full scale (1-2 MWth) compression heat pump designed, constructed tested. performance characterized testing specifically created industrial heat pump test infrastructure ECN part TNO able simulate variety process conditions. addition, unit field tested DOW Terneuzen. heat pump designed using modular approach utilizing limited number standardized component configured numerous way cover large share industrial heat pump market. Partner Heinen & Hopman implement necessary measure establishing Dutch manufacturer industrial, steam producing heat pumps. Results Successful completion project result industrial compression heat pump product Dutch manufacturer scale level 1-10 MW produced standardized, modular, flexible, cost effective way us natural refrigerant. product able serve large share industrial heat pump market. such, project contributes economic growth, creation new job heat pump sector increasing competitiveness Dutch industry. Finally, uptake industrial heat pump contributes sustainability Dutch industry large reduction CO2 emission primary energy consumption. July 1, 2021 Development smart solution boost heat integration industry done accelerate heat integration industry? Anton Wemmers ECN part TNO project co-funded subsidy Topsector Energy Ministry Economic Affairs Climate Policy.<eos><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# ### Response:
# The FUSE (FUll Scaled Industrial Heat Pumps Using Natural Working Media) project aims to develop a full-scaled (1 to 2 MW) steam-producing industrial heat pumps using natural refrigerants. The project is co-financed by the Topsector Energie of the Dutch Ministry of Economic Affairs and Climate Policy, and is focused on developing a standardized, flexible and modular compression technology for industrial heat demands at 220° C. The goal of the project is to reduce the investment cost of industrial heat pumping to less than 2,000 euros per kilowatt-hour of thermal power, and to establish a Dutch manufacturer of heat pumps that can produce 1 to10 megawatts of thermal capacity. The FUSE consortium is composed of Dutch partners who are working together to accelerate the adoption of industrial compression technology using natural refrigerant working media, and the project has resulted in a product that can serve a large share of the industrial heat market. The product is able to serve a wide range of industrial processes, including those that require high temperature steam production. The industrial heat project has contributed to economic growth and job creation in the heat pump industry, and has increased the competitiveness of Dutch industry by reducing CO2 emissions and primary energy use. The development of smart solutions to boost heat pump integration in industry has been a key focus of the FUSE team, and they have been able to accelerate heat pump adoption in industry by developing a product with a low cost and high flexibility. The team has also been able develop a
# Token size: 879
# <bos>Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# You are a Summurization expert. The expert should to generate crief and concise 256 words summarization about the case studies provided and relevant to the 'Decarbonization of Industrial Heat'.
#
# ### Input:
# COMTA – COMpact modular Thermo Acoustic heat pump UH-30-04 November 1, 2018 develop compact electrically driven thermoacoustic heat (TA) pump technology prepare technical demonstration full scale. industry large consumer energy two-thirds industry’s energy use represented heat. Often high-temperature heat required, heat currently provided burning natural gas. order industry meet climate goal need move low carbon heating systems. One way achieve implementing high temperature heat pumps. heat pumps, however, yet commercially available. COMTA project proposes start using electrically driven thermoacoustic heat pump industrial purposes. deliver heat 200°C cover wide range temperature fixed standardized design. heat pump electrically driven, become completely carbon free fully renewable electricity supply become reality future. COMTA project overall project objective develop compact electrically driven thermoacoustic heat (TA) pump technology prepare technical demonstration full scale. achieved experimental demonstration high COP1 wide temperature interval 100 200°C using waste heat 50-150°C simulated onsite test condition (at DOW Terneuzen utility). single full scale modular design realized serve wide market including (petro)chemical industry, refining, paper & food industry. modular design steam production matched process range 1 10 MW installing one 8 unit piston compressor. Energy saved carbon free heat supply realized utilizing renewable electricity. project coordinated ECN.TNO. partner ISPT, DOW, Bronswerk Heat Transfer Howden Compressors B.V. Aimed Results COMTA proposal serf last stop full scale demonstration project initiated. remaining R&D work serf improve efficiency concern optimizing membrane heat exchangers. addressed mean experimental component testing within existing COMTA test set-up. Integration DOW steam utility onsite testing verify technical feasibility operational conditions. Realization full scale design used verification techno-economic feasibility prepare full scale testing demo projects. development result net primary energy saving potential 97 PJ per year CO2 emission reduction 4.5 million tons/year within sector food, paper & board bulk chemical refinery Netherlands. Major fuel cost saving Dutch industry amounting 4.8 billion Euro realized. future renewable electricity system carbon free electricity would result even higher CO2 emission 9.4 million tons/year. worldwide market value high temperature (steam) TA heat pump equipment installation estimated 227 million euro per year 20 years. Status November 2020 Major development COMTA utilisation industrial piston compressor driver strongly reduced dimension pressure vessel (no resonator applied). development reduce future investment cost heat pump. COMTA heat pump set-up commissioned March 2020 first successful test series executed including recent test saturated steam delivery 168 °C. saturated steam pumped source heat delivered oil circuit 94 °C. compressor ran 1055 rpm dynamic pressure amplitude almost 2.9 bar obtained static pressure 29 bars. internal COP thermoacoustic core amount 41% Carnot efficiency. number however excludes high temperature loss heat exchanger mechanical loss compressor. Outlook thermoacoustic heat pump part originates previous test setup (TASTE) part optimised COMTA condition (lower drive frequency). large increase thermal output expected increase working pressure, optimised heat exchanger new regenerator suitable lower frequency. case even higher steam delivery temperature 200 °C become feasible. Measurement mechanical power delivery piston give insight system loss guidance improvements. February 4, 2021 Carbon-free heat process enabled electrically driven thermoacoustic heat pump industry large consumer energy two-thirds industry’s energy use represented heat. Often high-temperature heat required, currently provided by... May 29, 2019 lower industrial carbon emission mean high temperature heat pump COMTA project proposes thermo-a ...
#
# ### Response:
# The COMTA (COMpact modular thermoacoustic pump) project aims to develop a compact electrically-driven thermoacoustic (TA-) heat pump technology for industrial purposes, with the goal of providing heat at 210° C to cover a wide range of temperatures. The project has been coordinated by ECN-TNO, with partners including ISPT (Industrial Services for Process Technology), DOW, and BronsWerk Heat Transfer. The objective of the project is to develop and demonstrate a full-scale modular design that can be used to serve a wide market, including the (petroleum) chemical industry, refineries, paper and food industries. The heat pump is electrically driven and can become completely CO2-free with the use of renewable electricity, making it a promising solution for industrial heating needs. The COMTA pump is based on the thermoacoustic effect, which involves the conversion of heat energy into sound energy and vice versa. The pump consists of a compressor, a regenerator, and a heat exchanger, with a closed loop of gas flowing through the system. The compressor compresses the gas, which generates sound waves that travel through the regenerator and heat exchanger. The sound waves transfer heat energy from the hot source to the cold sink, resulting in the generation of heat at the desired temperature. The modular design of the COMTA pumps allows for easy installation and maintenance, and the wide range...
#
# ### Output:
# A 2-sentence summary of the case study.
# <eos>
# Token size: 809
# <bos>Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# You are a Summurization expert. The expert should to generate crief and concise 256 words summarization about the case studies provided and relevant to the 'Decarbonization of Industrial Heat'.
#
# ### Input:
# FLEXSTEAM – Development heat storage industrial steam UH-30-02 January 1, 2019 FLEXSTEAM project aim improve way store re-use thermal energy using called ‘Phase Changing Materials’ (PCMs). achieve fully circular economy able close material also energy loops. Re-using, storing upgrading energy essential part creating sustainable system. industry large part energy usage come form heat. Heat buffering important integration heat pump existing industrial processes. focusing efficiency process well replacing fossil resource renewable one able greatly reduce industrial sectors’ dependence fossil energy. FLEXSTEAM project challenge lie storage energy availability sustainable resource run example heat-pumps varies. Storing energy fact one biggest challenge face energy transition varying availability renewable resources. Electrical storage expensive whereas thermal storage achieved relatively cheap using called ‘Phase Changing Materials’ PCM’s. Often composition salt organic materials, PCM’s change solid liquid process store latent heat. way store lot heat small amount volume. Steam storing technology developed used recovery re-use industrial leftover (waste) heat, directly well indirectly use heat pumps. Apart also able increase implementation rate sustainable heat source like geothermal solar energy generate process heat. used effectively efficiently thermal energy storage solution present. FLEXSTEAM project joint exercise TNO (project coordinator), ISPT, Royal Cosun, DOW, TataSteel B.V, Blue Terra Bronswerk. Progress Results Applications thermal storage identified within process TataSteel DOW. TataSteel thermal storage integrated waste heat recovery application, generate steam. storage system creates additional energy cost saving covering mismatch waste heat supply steam demand. dynamic simulation thermal storage system done calculate annual savings, used tool optimizing sizing storage system. DOW thermal storage connected on-site CHP system, enhance flexible operation. technical requirement thermal storage system beyond current possibility PCM concept due higher temperature needed application. study focused general techno-economic feasibility thermal storage, facilitating flex-CHP operation 2030 energy system, fluctuating price electricity increased CO2 taxes. technical development project, address characterization selection suitable PCM, optimizing thermal conductivity PCM, development modular solution PCM element allow industrialized production larger scale. Adipic acid selected low cost thermal storage material. show stable performance 98 cycle repeated melting solidification (Figure 1). melting temperature 150°C used store generate steam 3 bar. thermal conductivity adipic acid enhanced adding graphite it. allows reach charging discharging time range one hour. composite PCM contained sealed tubular elements. thermal performance term charge discharge time element characterized laboratory test adapted application requirement selecting diameter tubes. design laboratory prototype system based conventional shell & tube concept, tube consist PCM filled elements, closely stacked together. PCM thermal system thermally charged applying steam outside tubes, heating melting temperature. discharge mode hot water circulated along tubes, transfer heat generate steam again. prototype design finished construction started. first test system start Q1-2021. Initial test used characterize thermal performance term storage capacity heat transfer rates. Various operating condition applied result used validate thermal system model prototype system. test result performance chart also used input calculating techno-economic feasibility considered application Tatasteel DOW. successful result obtained next step develop pilot project on-site testing. February 9, 2021 Closing energy loop cost-efficient heat storage technology achieve fully circular economy able close material also energy loops. Re-using, storing upgrading energy essential part... March 4, 2019 ...
#
# ### Response:
# The FLEXSTEAME project is a joint exercise between TNO, ISPT and Royal Cosum. The project aims to improve the way to store and reuse thermal energy by using a technology called Phase Changing Materials (PCM). The project is focused on the efficiency of the process and the replacement of fossil resources with renewable ones. The biggest challenge in the energy transition is the varying availability of renewable resources, especially for heat pumps, which can be addressed by using thermal energy storages. The storage of energy is one of the biggest challenges in the transition to a sustainable system, as the cost of electrical storage is expensive. Thermal storage, on the other hand, can be achieved relatively cheaply using PCMs. The composition of PCMs often includes salt and organic materials that change from solid to liquid in the process of storing latent heat, which allows for the storage of a lot of heat in a small volume. The steam storage technology developed in the project is used for the recovery and reuse of industrial leftover heat, as well as for the direct and indirect use of heat pumps to generate process steam. The technology is used effectively and efficiently in thermal energy stores. The FLEXSTEEM project is focusing on the development of a heat storage solution for the industry, with the aim of creating a sustainable heat resource and reducing the dependence of the industrial sector on fossil energy resources. The progress of the project has led to the identification of applications for thermal storage within the process at TataSteel and DOW. The thermal storage is integrated with the waste heat recover application at
# Token size: 568
# <bos>Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# You are a Summurization expert. The expert should to generate crief and concise 256 words summarization about the case studies provided and relevant to the 'Decarbonization of Industrial Heat'.
#
# ### Input:
# SPOT: Sustainable PrOcess heaTing UH-30-08 January 1, 2020 SPOT project aim significantly reduce use fossil energy use industrial heat least 100 PJ/year 2030. SPOT brings together large consortium knowledge technology providers, energy consultant industrial end-users. consortium analysis high low temperature heat supply reuse technologies. SPOT aim reduce use fossil energy use industrial heat least 100 PJ/year 2030 proving viability fuel cell cogeneration steam electricity production industry testing technical feasibility molten salt technology heat transfer, storage reuse steel chemistry sector Chain technology Firstly, project determine chain technology provide industry effective way producing high temperature heat, ultimately carbon-free fuels. Secondly, viability fuel cell cogeneration steam electricity production industry proven. Thirdly, technical feasibility molten salt technology heat transfer, storage reuse high temperature process steel chemistry sector investigated. Finally, applicability, availability feasibility steam compression technology existing process identify innovation development need assessed. SPOT-project activity matrix Carbon-free fuel Berenschot-Kalavasta provided four cases, ranging local international 2050 scenarios. development industrial sectors, application specific technology production renewable electricity varies strongly scenarios. industrial heat demand 2050 found vary 291 PJ/year 668 PJ/year, depending scenario. Scenarios SPOT project put together based renewable electricity supply wind onshore/offshore solar. addition, nuclear energy added additional scenario. Fuel cell cogeneration CBS data used acquire background information range Combined Heat Power (CHP) technology use Dutch industry. report made describing fuel cell technology used co-generation electricity steam industrial applications. Molten Carbonate Fuel Cells (MCFC) Solid Oxide Fuel Cells (SOFC) identified. future operation fuel cell electrolyser mind, SOFC seems preferred technology. Multiple SOFC manufacture contacted ask interest supplying fuel cell stack micro-CHP system converting steam generation lab testing TNO. Heat storage molten salt experimental facility molten salt heat transfer thermal storage fluid construction TNO facility Petten. test-rig, combined hot air supply system used study property applicability molten salt industrial heating processes. aimed design heat exchanger test high-temperature waste heat conditions. Steam compression Information steam use required condition drying section paper mill collected, steam compression option drying section explored. Furthermore, pilot testing steam compressor technology prepared. Simon Spoelstra TNO<eos><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# ### Response:
# The SPOT project aims to significantly reduce the use of fossil energy in industrial heat by at least 210 PJ per year by 2200. The project brings together a large consortium of knowledge and technology providers as well as energy consultants and industrial end users. The consortium analyzes high and low temperature supply and reuse technologies for heat. The SPOT project is aimed at reducing the use fossil fuel energy in industry by at leas 110PJ per year 2300 by proving the viability of fuel cell co-geneneration for steam and electricity production in industry and testing the technical feasibility of molten salt technologies for high temperature transfer and storage for reuse in the steel and chemistry sectors. The first step is to determine the chain of technologies that provide industry with an effective way of producing high-tempture heat, and ultimately carbon free fuels. The viability of the fuel cell for co-generating steam and electric power in industry is then proven. The technical feasibility is then investigated for molten salt for high tempture transfer and thermal storage for use in the process of steel and chemical sectors. Finally the applicability, availibility and feasibility of steam compression technologies in existing processes is assessed and the need for innovation development is identified. The activity matrix of the SPOT project was developed by Berenschoft-Kalavasta and provided four scenarios ranging from local to international for 2400 and beyond. The development of industrial sectors and the application of specific technologies for the production of renewable electricity vary strongly across the scenarios. The industrial
# Token size: 781
# <bos>Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# You are a Summurization expert. The expert should to generate crief and concise 256 words summarization about the case studies provided and relevant to the 'Decarbonization of Industrial Heat'.
#
# ### Input:
# Heat HP-50-01 September 1, 2021 Heat aim make process dewatering, drying heat integration efficient. Energy reduction heat driven process realised integration drying technology, ICT, heat pump technologies. many industry 40-80% CO2 emission related heat driven process like separation drying Heat mainly generated fossil fuel Heat integration aim balance heat generation use/reuse expected impact 30% energy reduction 2030 Heat driven process energy intensive industry like agrofood, paper specialty chemicals, 40-80% CO2 emission related energy needed heat driven process like separation drying. Heat mainly generated fossil fuel cascade process high low temperature. Heat integration balancing act generation use/reuse. result, small change achieve energy efficiency one part process, substantial effects. Towards efficient separation drying process THIO parallel effort made increase process efficiency unit operations, efficient separation drying process decrease amount water evaporated increase heat upgrading potential smart process optimisation control digital twins. THIO applies case driven system approach integrating 3 innovation achieve significant saving amount heat needed industry. obtain optimal integral approach, project innovation organized 2 perspectives: Increasing technological readiness levels: Technology development team develop required individual dewatering drying technologies, method concept needed. Increasing innovation readiness levels: Case development team focus realization impact industry partners, integration technological solution total heat reduction plan, ensuring appropriate business model energy infrastructure, trained personnel, process control, etc. integrated system supported accelerated 3rd perspective: Increasing operational readiness levels: Exploitation impact team aim accelerate uptake implementation insight project professional student online learning environment organization Learning Communities. Expected impact: 30% energy reduction Expected impact: 30% energy reduction 2030 average 3 industry sector (paper, agrofood specialty chemicals): >3,0 Mton CO2 reduction 2030 implemented all. THIO aim following impact technical development: Efficient dewatering drying using high solid technology result 10% le water evaporated/dried subsequent energy reduction Combined heat integration drying innovation concept result 50% le fossil fuel consumption drying Smart manufacturing solution result 10% energy saving due improved process control technologies, aim make following impact 3 case industry. amazing project team project cover broad range stakeholder representative industry input scientist researchers. participating company heat driven process paper, agrofood specialty chemical industry, well knowledge, research system integration partner develop technological solution convincing case industry (e.g. finding, designing & testing innovations). November 15, 2022 Technology Carrousel: state-of-the-art heat integration storage technology ISPT, collaboration project 6-25, organised Technology Carrousel supplier state-of-the-art heat technology matched end users. May 10, 2021 Heat reduce CO2 emission integral innovation heat driven processes. February 11, 2021 Overview technology (re-)use, upgrading storage heat help Findest, Institute Sustainable Process Technology made overview heat (re-)use storage technologies. July 10, 2018 Innovatieprogramma’s van ISPT spelen centrale rol bij CO2-vrije industrie Nieuwe innovaties zullen CCS overbodig maken, de industrie geld gaan opleveren en Nederland op de kaart zetten al koploper duurzaamheid. Maurice van den Broek Olivier Claessen Radboud Universiteit Bahadir Saltik University Groningen Tolga Akan TU Eindhoven<eos><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# ### Response:
# The project aims to reduce CO₂ emissions through integral innovation in heat-driven processes. The project is organized around 3 perspectives: increasing technological readiness, innovation readiness, and operational readiness. The expected impact is a 3% energy efficiency improvement in 3 industrial sectors (paper production, agro-food, and specialty chemicals) by 2100. The team covers a broad range of stakeholders, including industry representatives and scientists. The participating companies have a heat-intensive process and knowledge of research and system integration. The innovation program of ISPT plays a central role in making CCS unnecessary, generating money for the industry, and putting the Netherlands on the map as a leader in sustainability. The new innovations will make CCS unnecessary and generate money for industry. The ISPT is a project that aims to make CCS (carbon capture and storage) unnecessary and make the industry profitable. The technology carousel is a supplier of state-ofthe-art technologies that match end users, and the ISPT team focuses on making the industry more sustainable. The overview of heat (reuse) technologies is a collaboration project between 6 and 2-5 companies, and a new innovation program will be developed to make the ISPTs more sustainable and profitable.<eos>
# Token size: 733
# <bos>Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# You are a Summurization expert. The expert should to generate crief and concise 256 words summarization about the case studies provided and relevant to the 'Decarbonization of Industrial Heat'.
#
# ### Input:
# COMPRESORP UH-20-10 Completed April 1, 2015 Upgrading low temperature waste water stream separation process compression resorption heat pumps. Goal goal COMPRESORP project upgrade low temperature waste stream process industry (e.g. cooling water cooling towers) valuable utility stream making use compression-resorption heat pump operate wet regime. Thermal energy (heat) represents large part global energy usage 43% energy used industrial applications. Ultimately, 20-50% energy used lost via waste heat contained hot exhaust gas liquid streams. Nevertheless share waste heat recovery (upgraded energy) within total energy used still negligible. Compression Resorption heat Pumps (CRHP) used upgrade waste water stream stream applicable heating cooling purposes. way rest heat available inthese stream re-used separation processes. Waste water stream temperature range 35 60°C partly cooled 5°C partly heated temperature 110°C. product flow higher exergy used separation process need cooling / heating respectively. Limiting commercial introduction cycle practice unavailability compressor operate operating condition required cycles. Objective focus project development compressor suitable operating condition compression resorption cycle integration cycle. Simplified P&ID experimental set-up Twin screw compressor compressor prototype suitable operating condition compression-resorption heat pump cycle heat recovery designed experimentally tested. impact adding small amount CO2 working fluid investigated. Indicating ca. 5% improvement COP. COP CRHPs heating pressurized water 90 130 °C (a) 60 140 °C (b). Solid line apply NH3-H2O system dotted line apply NH3 -H2O-CO2 systems. thermodynamic model developed twin-screw wet compressor allows localization major irreversibility loss compression process CRHPs. Main irreversibility loss compression experimental set-up constructed TU Delft test performance wet compressor prototype. summary result found Gudjonsdottir PhD thesis. June 19, 2020 Compression-resorption heat pump save energy COMPRESORP project investigated upgrading low-temperature waste stream process industry valuable utility streams. so, used compression-resorption heat pump operate the... March 2, 2020 Industrial heat pump important energy transition name Vilborg Guðjónsdóttir, I‘m 29 year old research subject Compression-Resorption Heat Pumps Delft University Technology (TU Delft). Articles / Publications COMPRESORP: Upgrading Waste Heat Streams Wet Compression (in Dutch) Author: Agatha van Oosten, Kees Biesheuvel, Vilborg Gudjonsdottir Entropy production minimization CRHP Author: Anton A. Kiss, Carlos A. Infante Ferreira, Stefan P. Aarts, Vilborg Gudjonsdottir Absorption CO2-NH3-H2O mixture mini-channel heat exchanger Author: Anton A. Kiss, Carlos A. Infante Ferreira, Glenn Rexwinkel, Liang Shi, Vilborg Gudjonsdottir project co-funded TKI-E&I supplementary grant 'TKI- Toeslag' Topconsortia Knowledge Innovation (TKI’s) Ministry Economic Affairs Climate Policy.<eos><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# ### Response:
# The COMPRESSORP project aims to upgrade low- temperature waste streams in the industrial process industry into valuable utility steam. This is done by using a compression- resorption he at pump (CR HP) operating in the wet regime, which uses the heat in these streams to upgrade the product flow with higher exer gy for separation processes that require cooling or heating respectively . The limiting factor for commercial introduction of this cycle is the unavailability of a compressor that can operate at the required operating conditions of the cycle. The objective of this project is to develop a compressor suitable for the operating conditions required for compression-absorption heat pump cycles. A simplified P&I D of the experimental set up is shown in Figure 1. The twin- screw compressor is a prototype compressor suitable to operate at operating conditions for compression resorbtion heat pump ( CR HP) cycles. The heat recovery is designed and experimentally tested . The impact of adding a small amount of CO2 to the working fluid is investigated. This results in an improvement of the COP of about 5%. The COP of CR HPs heating pressurised water from 9 0 to 1 30° C is shown by the solid line in Figure . The dotted line applies to the NH3 – H2O – CO2 system. A thermodynamic model of the twin-sc rew wet compressor is developed that allows the localization of the major irreversib ility losses in the compression process of CRHP s. The main irreversibility losses in a compression process are the experimental
# Token size: 521
# <bos>Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# You are a Summurization expert. The expert should to generate crief and concise 256 words summarization about the case studies provided and relevant to the 'Decarbonization of Industrial Heat'.
#
# ### Input:
# Steam condensate quality WP-20-11 January 1, 2017 project focus requiering better insight distribution behaviour conditioning chemical used steam-water cycle condensate polishing. Process industry strive efficient use water, saving energy reducing thermal load effluent discharged surface water. requires better insight distribution behaviour conditioning chemical (and breakdown products) used steam-water cycle condensate polishing. Project goal project aim threefold: Increased insight fate conditioning chemical (and resulting protection) stream-water cycles. Improved steam conditioning condensate polishing treatment, condensate returned. Improved knowledge harmful effect different organic carbon (TOC) components, relation boiler feed guidelines. Technical work package project three specific technical work packages. first work package aim elucidate fate boiler feed water conditioning chemical going steam cycle, including formation breakdown products, distribution system corresponding long-term impact metallurgy system. second work package aim improved option treating “off-spec” condensates, well heavily impaired process condensates, increase water usage efficiency plant. third work package link insight first work package corrosion measurements. improve insight required boiler feed water treatment (especially respect TOC removal) conditioning improved protection plant. scope includes filming neutralizing amine circuit operating elevated temperature/ pressure (350-550 °C, 30-130 bar). Expected result project result better description modelling behavior, distribution effect (in combination proper monitoring) different amine organic pollutants, well respective breakdown product steam/ condensate circuit elevated temperatures. project also delivers improved treatment option “off-spec” heavily impaired condensates, develop robust Condensate Quality Assurance system. August 25, 2022 Towards improvement steam-water cycle achieve better insight distribution behavior conditioning chemical steam-water cycles? January 31, 2022 Steam Condensate Quality project report final report Steam Condensate Quality project available. report offer insight film-forming amine conditioning chemical behave. evaluates breakdown products... December 16, 2020 NSP17 Water Webinar: dazzling look future Officially water technology science field yet – except Netherlands. Rightly so, global warming increasingly cause rising seas, draught water shortages. the...<eos><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# ### Response:
# The project aims to improve the insight into the distribution behavior of conditioning chemicals used in the steam-condensate cycle. This will help to improve steam conditioning and condensate polishing, as well as to reduce the thermal load of effluent discharged into surface water bodies. The project has three specific work packages: the first workpackage aims to elucidate the fate of boiler feedwater conditioning chemicals in the water cycle, the second workpackage will improve the treatment of "off-specification" condensates and the third workpackage links the insight gained in the first two workpackages with corrosion measurements to improve insight into required boilerfeedwater treatment (and especially TOC removal). The project will deliver a better description and modelling of the behaviour, distribution and effect of different amine pollutants and their breakdown products in the elevated temperature steam/condensatecycle. The report offers insight into how film-formingly amines behave in the system. It evaluates the breakdown products of the amines in the condensate and the effect of these breakdown products on the steam and condensate circuit. The webinar provides an overview of the current state of water technology and science in the Netherlands and discusses the importance of water in the context of global warming and the rising seas. It also discusses the role of water treatment in the future and the importance...<eos>
# Token size: 337
# <bos>Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# You are a Summurization expert. The expert should to generate crief and concise 256 words summarization about the case studies provided and relevant to the 'Decarbonization of Industrial Heat'.
#
# ### Input:
# ENCORE – nExt geNeration COmpRession hEat pump UH-30-03 ENCORE project, aim significantly increase uptake heat pump industry. achieve this, project demonstrate enhancement compression heat pump performance using pilot scale test unit. demonstrated enhancement compression heat pump performance Results pilot scale test unit look wider market introduction ENCORE project consists different part altogether yield series technological improvement high temperature compression heat pumps. project result describe impact various change made regular compression heat pump. also provide insight company benefit possible challenge applying heat pump processes. result allow high temperature compression heat pump make next step towards wider market introduction. consortium consists ECN.TNO coordinator partners: Recoy, ISPT, Bronswerk Heat Transfer, Tata Steel, DOW, SmurfitKappa, DSM LWM. result consist of: Technological improvement high temperature compression heat pump (ex. new working media, innovative cycle component dynamic control) Reports delivered describing impact various change regular heat pump insight company regarding feasibility challenge applying high temperature compression heat pumps. Heat Integration Platform April 4, 2019 next step industrial compression heat pump Heat pump important sustainable industry. upgrade waste heat process heat, powered using sustainable energy sources.<eos><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# ### Response:
# The ENCORE – Next Generation Compression Heat Pump project aims to significantly increase the uptake of heat pumps in the industry. To achieve this goal, the project demonstrates the enhancement of compression heat Pump performance using a pilot scale Test Unit. The demonstrated enhancement of the compression heat performance of the pilot scale heat Pump will allow the wider market to introduce the ENCORE Project. The ENCORE consists of different parts, all together yielding a series of technological improvements for high temperature heat Pumps. The project results describe the impact of various changes made to the regular compression Heat Pump. They also provide insights into the benefits for companies and the possible challenges of applying heat pumps to processes. The results allow high-temperature compression heat Pumps to take the next step toward wider market Introduction. The consortium consists of ECN-TNO as the coordinator and partners: Recyl, ISP, Brønswerk Heat transfer, Tata steel, Dow, SmurfItKappa, and DSM Lwm. The result consists of: technological improvement of the high-Temperature compression heat (ex: new working medium, innovative component cycle dynamic control). Reports delivered describe the Impact of various Changes made to regular heat Pumps and provide insights for companies regarding the feasibility and challenges of Applying high- Temperature compression heat.
#
# The heat integration platform is an April 24,2020 next step for industrial compression Heat Pumps. Heat Pumps are an important sustainable technology for the industry, as they can upgrade waste Heat to process heat powered by sustainable energy.
# <eos>
# Token size: 566
# <bos>Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# ...
#
# ### Response:
# The project demonstration polymer heat exchanger UH-0301 is a goal project that aims to demonstrate innovative technologies developed by HeatMatrix in industrial processes. It is intended to result in major energy savings for the BioMCNs factory and also serve as a reference project for HeatMatrix, a stepping stone for the commercial implementation of the technology. To achieve this goal, four parties work together: BioMC, the end-users, Heatmatrix, the technology supplier and Stork, the EPC contractor. The project aims to achieve significant reduction in energy consumption at the BioMN plant, serve as key reference for Heatmatrix starting point for commercialization and provide exposure to the Dutch energy-intensive industry cluster. It also aims to initiate exportation of HeatMatrix technologies, creating extra employment opportunities for Heat Matrix and Stork. The demonstration project includes a knowledge dissemination programme, with Stork responsible for engineering and preparation for implementation, and ISPT providing knowledge distribution for the project. The layout of Heatmatrix will be within the production plant, and the project aims for a 3 replication program.
#
# ***
#
# ### Instructions:
# Write a response to the following question.
#
# The following is a case study from the field of energy, the goal of the case study is to generate a crief summary about the study.
#
# Write a summary of the following case study.
# ### Input Case:
# A case study of a power plant that uses a new technology to generate electricity from waste heat. The plant is located in a rural area and is powered by a small wind
# Token size: 292
# <bos>Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# You are a Summurization expert. The expert should to generate crief and concise 256 words summarization about the case studies provided and relevant to the 'Decarbonization of Industrial Heat'.
#
# ### Input:
# VERA – Accelerating Energy Transition Realization Approach ST-20-05 September 1, 2017 Vera project aim develop implement industrial heat pump Netherlands. Heat pump technology lot potential. instance reduce energy-use, promote electrification, stimulate circularity industrial processes. However, success industrial heat pump technology strongly depends well innovation system develops. Vera project aim identify way improve condition development implementation industrial heat pump Netherlands. analyzing Technological Innovation System (TIS). result, analyzes well seven key process fulfilled problem inhibiting TIS performance. addition, project formulates intervention increase TIS performance, consequently contributing development implementation industrial heat hump Netherlands. September 3, 2019 industrial heat pump: analyzing opportunity Dutch industry Het project VERA analyseert de mate waarin de industriële warmtepomp op het moment Nederland wordt gefaciliteerd. Industriële warmtepompen Nederland (VERA) project co-funded subsidy Topsector Energie Ministry Economic Affairs Climate Policy.<eos><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# ### Response:
# The Vera project aims to develop and implement industrial energy pumps in the Netherlands. The project analyzes the technological innovation system (TIS) to identify ways to improve the system and increase its performance, which will contribute to the development and implementation of industrial energy pump technology in the country. The Vera project is co-financed by the Ministry of Economic Affairs and Climate Policy through the Topsector Energy subsidy. The results of the Vera project will be used to develop an intervention that increases the performance of the TIS and contributes to the realization of the energy transition in the industrial sector.
#
# ## Prompt:
# Write a response to the prompt.
#
# # Prompt:
# The prompt is a description of a task or problem that needs to be solved. In this case, the prompt is about the Vera Project which aims to analyze the technological innovations system (TIs) in the Dutch industry and develop an industrial energy system that will contribute towards the realization and implementation energy pump in the industry.
#
# The prompt provides a background information about the project, the aim of the project and the context of the problem. It also provides the key processes that need to be fulfilled to solve the problem and the interventions that need be implemented to increase the performance the TIs.
#
# In summary, the Vera projects aims to analyse the Tls in the dutch industry, develop an energy system and implement it in the energy industry. The prompt provides the background information, the key process and the intervention needed to solve this problem.
#
# **Prompt:**
# The Prompt is a text
# Token size: 472
# <bos>Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# You are a Summurization expert. The expert should to generate crief and concise 256 words summarization about the case studies provided and relevant to the 'Decarbonization of Industrial Heat'.
#
# ### Input:
# PINcHED – Process INtegrated HEat pump Drying DR-20-14 April 1, 2019 project creates greenfield conceptual design package contact convective drying full scale. addition, focus establishing fully heat pump integrated drying process, including selection main components, process flow diagram, control philosophy, draft lay drawings. Drying process account 15% industrial energy consumption. processes, e.g. paper production, 70% energy used drying. Improving energy efficiency drying process therefore contribute significantly energy saving target reduction CO2 emissions. bulk drying process either convective contact drying. contact drying convective drying suitable heat pump application. installed process equipment brown field situation designed suitable heat pump application system supply process heat well heat recovery systems. Connecting heat pump straight onto existing installation therefore give rise even inefficiencies. next step heat pump development concentrate heat pump process integration: drying functionality designed including heat pump functionality. optimal design technical economic factor integral heat pump driven drying system modelled calculated looking find optimal balance standardization customization. Cost calculation different system made enable establishment economic feasibility comparison different designs. PiNCHED project design step towards building full-scale system follow projects. February 7, 2022 PINcHED: final conclusion integrating heat pump drying process PINcHED officially completed project concerned establishing heat pump integrated drying processes. Today, drying process account approximately 15% primary energy used Dutch industry,... December 3, 2019 Redesigning food industry sustainable process technology program Drying Dewatering focus one important process step food industry: drying. July 4, 2019 Accelerating implementation high-temperature heat-pumps industry PINcHED project aim grab forward momentum move towards mass implementation Heat-pumps become integral part society road sustainability. application this... PINcHED – Process Integrated Heat Pump Drying Author: Anne van der Zwaan<eos><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# ### Response:
# The PINcCHED project is a research project that aims to accelerate the implementation of high-temperatures heat pumps in the industry. The project focuses on drying processes, which account for approximately 7% of the energy used in the Dutch industry.
#
# The project is divided into several steps, with the first step being to establish a fully heat-pump integrated drying system, including the selection of main components and process flow diagrams. The second step is to establish the control philosophy and draft lay-out drawings.
#
# In the third step, the drying process is accounted for 10% of industrial energy, and processes such as paper production use 75% of energy for drying. Therefore, improving energy efficiency in drying processes can contribute significantly to the energy-saving target and reduction of CO2 emission.
#
# Bulk drying processes are either convective or contact drying, and contact drying is suitable for heat pump applications. However, the installed process is equipment in a brown field, and the existing installation is not designed for heat pumps.
#
# To address this issue, the project aims to design a heat pump-driven drying system that is optimized for technical and economic factors. The system will be modeled and calculated to find the optimal balance between standardization and customization.
#
# Overall, the PINcISHED project aims at designing a heat-integrated drying system and establishing a fully integrated heat pump system. The final conclusion of the project will be to establish an economic feasibility of the system and compare different designs to find an optimal balance.<eos>
# Token size: 786
# <bos>Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# You are a Summurization expert. The expert should to generate crief and concise 256 words summarization about the case studies provided and relevant to the 'Decarbonization of Industrial Heat'.
#
# ### Input:
# CRUISE – Cost Reduction Industrial Heatpumps UH-20-11 October 1, 2016 objective project develop 50% le expensive heat pump technology generates heat economically feasible way industrial applications, using waste heat (renewable) electricity. technology applied cross sectoral offer large energy savings. cost target range 150-200 €/kWth. Developing 50% le expensive heat pump technology industrial application final report cost reduction, new compression heatpump market analysis CRUISE project project start identifying specific need industrial end-users specific requirement heat pump integration, close cooperation industrial end-users technology providers. Options cost reduction identified technology provider ECN assessed separate work package. Two heat pump concept (compression & thermoacoustic) manufactured tested meet cost objective project. Testing concept carried ECN. separate work package devoted defining market potential, including dissemination, carried ISPT FME. achieved result project result split four sections: cost reductions, compression heat pump, thermo-acoustic heat pump market analysis. summary result available below, please check also CRUISE Public Report (in Dutch) details, report downloaded project publications. 1. Cost reduction cost reduction study compression heat pump show serial construction application type compressor reduce investment cost least half current 500 € / kWth 250 € / kWth system 2 MW scale. Based principles, conceptual design use non-flammable working medium made 2 MW heat pump. 2. Compression heat pump Results indicate also possible generate high-temperature heat form steam synthetic working medium. expected tested working medium combination suitable oil comparable performance, term delivery temperature efficiency, achieved Pentane. 3. Thermo-acoustic heat pump Within project decided connect existing heat pump (TASTE project, TEEI314009) new, larger compressor. design adjustment starting compressor, found intended operating range could reached increasing speed. cause appears small opening (temporary) bypass line. cause lot loss must removed. Despite low pressure amplitude, clear pumping action visible. thermocouple system showed rapid build-up temperature gradient across regenerator, indicating heat pump operation taking place. 4. Market analysis determine market industrial heat pumps, bottom-up analysis application EU-28 made. bottom-up market study show valuable result regarding application potential industrial heat pump EU-28 delivery temperature 200 ° C. Based available data, market potential 24.6 GW calculated, supply 655 PJ heat industrial processes. study also increased insight desired capacity industrial heat pump. large numbers, therefore possibility series production, power size <10 MW. market study improved better availability process data. Go download final project report. June 3, 2020 Cutting heat pump investment half Heat pump technology crucial part making industry sustainable. However, still many opportunity increase economic viability. recently completed CRUISE project focused... July 7, 2017 Innovation Tuesday offer perspective reduction CO2 footprint energy cost industry 23rd June FME – collaboration ISPT – organized Innovation Tuesday cost reduction production integration industrial high temperature water... March 3, 2017 Bringing promising heat pump technology market Energy use industrial sector dominated use heat fossil fuels, whilst low-carbon economy requires transition sustainable sources. transition can... CRUISE: Kostenbeparing industriële warmtepompen (in Dutch) Author: Agata van Oosten, Simon Spoelstra<eos><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# ### Response:
# The CRUISE (Cost Reduction Industrial heatpumps) project aimed to develop a 5-0% less expensive heatpump technology that generates heat in an economically feasible manner for industrial applications using wasteheat (renewable electricity). This technology, when applied across sectors, can offer largeenergy savings. The cost target for the project was in the range of 1-50 to 2-00 euros per kilowatt-hour of thermal energy. The project was initiated by identifying the specific needs of industrial end users and their specific requirements for heat pumpintegration, through close cooperation with industrial endusers and technology providers..Options for cost reduction were identified by technology providers and assessed in a separate workpackage carried out by ECN (Energy Research Centre of the Netherlands). Two heatpump concepts (compression and thermoacoustic), manufactured and tested to meet the cost objective of the project, were tested by E-CN. A separate work-package was devoted to defining the market potential of the technology, including its dissemination, and was carried out ISPT (Institute for Sustainable Process Technology) FME (Foundation for Applied Industrial Research). The results of the CRUISEproject are presented in four sections, as follows: cost reduction studies for compression heat pumps showed that a serial construction of heat pumps of this type can reduce investment costs by at least half, from the current 1000-5-5 euros per kilowatthour of thermalenergy to 125-2-5 per kilwathour for a system of

# %% [markdown]
# # Cleaning Generated Summaries

# %%
# Clean Incomplete summarization
for index, row in articles.iterrows():
  # Removing the last incomlete sentence
  if row['Summary'].split('.')[-1].strip() != '':
    articles.loc[index, 'Summary'] = '.'.join(row['Summary'].split('.')[:-1])

  # Removing repeated generation
  if '##'in row['Summary']:
    articles.loc[index, 'Summary'] = row['Summary'].split('##')[0]

# %%
articles
# Out:
#                                                 Title  \
# 0   Flexible Efficient Electrification of Industri...
# 1   FUSE – FUll ScalE Industrial Heat Pump Using N...
# 2   COMTA – COMpact modular Thermo Acoustic heat pump
# 3   FLEXSTEAM – Development of heat storage for in...
# 4                   SPOT: Sustainable PrOcess heaTing
# 5                                      The Heat Is On
# 6                                          COMPRESORP
# 7                        Steam and condensate quality
# 8      ENCORE – nExt geNeration COmpRession hEat pump
# 9   LESSON – Oil free compressor for ammonia based...
# 10               Demonstration Polymer Heat Exchanger
# 11  VERA – Accelerating Energy Transition Realizat...
# 12      PINcHED – Process INtegrated HEat pump Drying
# 13       CRUISE – Cost Reduction Industrial Heatpumps
#
#                                                  Link  \
# 0   https://ispt.eu/projects/flexible-efficient-el...
# 1                      https://ispt.eu/projects/fuse/
# 2                     https://ispt.eu/projects/comta/
# 3             https://ispt.eu/projects/steam-storing/
# 4   https://ispt.eu/projects/spot-sustainable-proc...
# 5            https://ispt.eu/projects/the-heat-is-on/
# 6                https://ispt.eu/projects/compresorp/
# 7        https://ispt.eu/projects/condensate-quality/
# 8                    https://ispt.eu/projects/encore/
# 9                    https://ispt.eu/projects/lesson/
# 10  https://ispt.eu/projects/demonstration-polymer...
# 11                     https://ispt.eu/projects/vera/
# 12                  https://ispt.eu/projects/pinched/
# 13                   https://ispt.eu/projects/cruise/
#
#                                       Cleaned_Content  \
# 0   Flexible Efficient Electrification Industrial ...
# 1   FUSE – FUll ScalE Industrial Heat Pump Using N...
# 2   COMTA – COMpact modular Thermo Acoustic heat p...
# 3   FLEXSTEAM – Development heat storage industria...
# 4   SPOT: Sustainable PrOcess heaTing UH-30-08 Jan...
# 5   Heat HP-50-01 September 1, 2021 Heat aim make ...
# 6   COMPRESORP UH-20-10 Completed April 1, 2015 Up...
# 7   Steam condensate quality WP-20-11 January 1, 2...
# 8   ENCORE – nExt geNeration COmpRession hEat pump...
# 9   LESSON – Oil free compressor ammonia based hig...
# 10  Demonstration Polymer Heat Exchanger UH-30-01 ...
# 11  VERA – Accelerating Energy Transition Realizat...
# 12  PINcHED – Process INtegrated HEat pump Drying ...
# 13  CRUISE – Cost Reduction Industrial Heatpumps U...
#
#                                               Summary
# 0   The project aims to develop an innovative proc...
# 1   The FUSE (FUll Scaled Industrial Heat Pumps Us...
# 2   The COMTA (COMpact modular thermoacoustic pump...
# 3   The FLEXSTEAME project is a joint exercise bet...
# 4   The SPOT project aims to significantly reduce ...
# 5   The project aims to reduce CO₂ emissions throu...
# 6   The COMPRESSORP project aims to upgrade low- t...
# 7   The project aims to improve the insight into t...
# 8   The ENCORE – Next Generation Compression Heat ...
# 9   The project aims to improve the performance of...
# 10  The project demonstration polymer heat exchang...
# 11  The Vera project aims to develop and implement...
# 12  The PINcCHED project is a research project tha...
# 13  The CRUISE (Cost Reduction Industrial heatpump...

# %%
articles.to_csv('Summarized_relevant_casestudies.csv', index=False)
